# %%
password = "open123"
User = input("Enter your password : ")

attempts = 3
while attempts > 0:
    if password == User:
        print("Access granted")
        break
    else 
    
        if attempts == 4:
            continue
        else :
            print(f"Wronge password, Attempts Left : {attempts}")
# Out:
# Enter your password :  Shub
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# Wronge password, Attempts Left : 3
# ...
